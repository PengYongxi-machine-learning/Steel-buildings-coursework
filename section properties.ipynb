# %%
import pandas as pd
import numpy as np

# %%
uc = pd.read_excel('UC.xlsx')
ub = pd.read_excel('UB.xlsx')

# %%
uc.head()
# Out:
#   Eurocode 3 (in accordance with the UK National Annex) (BS EN 10365: 2017)  \
# 0                                                NaN
# 1         Universal columns (UC), Section properties
# 2                            Dimensions & properties
# 3                                                UC
# 4                                Section designation
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN        NaN        NaN         NaN        NaN        NaN
# 1        NaN        NaN        NaN         NaN        NaN        NaN
# 2        NaN        NaN        NaN         NaN        NaN        NaN
# 3        NaN        NaN        NaN         NaN        NaN        NaN
# 4        NaN        NaN        NaN  Dimensions        NaN        NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 21 Unnamed: 22 Unnamed: 23  \
# 0        NaN        NaN        NaN  ...         NaN         NaN         NaN
# ...
